# %%
#pip install gradio

# %%
import ollama
import gradio as gr

# %%
system_msg = "You are an expert electric vehicle conversion engineer specializing in converting petrol motorcycles into electric bikes."

# %%
# Chatbot function
def CustomLlama3(user_input):
    # Format the conversation context
    messages = [
        {"role": "system", "content": system_msg},
        {"role": "user", "content": user_input}
    ]

    # Generate response using Ollama's Llama 3 model
    response = ollama.chat(model="llama3", messages=messages)

    # Extract and return response text
    return response['message']['content']

# %%
# Gradio Interface
demo = gr.Interface(fn=CustomLlama3, 
                    inputs="text", 
                    outputs="text", 
                    title="E-bike Conversion Assistant")

# %%
# Launch the app
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# Output:
# Exciting project! Converting your TVS XL Heavy Duty motorcycle to an e-bike can be a fantastic way to reduce emissions and increase fun on the roads. As an expert electric vehicle conversion engineer, I'd be happy to guide you through the process.
#
# Before we begin, let's consider a few things:
#
# 1. **Motor**: We'll need to choose a suitable motor for your TVS XL. Electric motors typically fall into two categories: hub motors (built into the wheel) or mid-motors (attached to the frame). Hub motors are generally easier to install and maintain, but mid-motors provide more power and control.
# 2. **Battery**: We'll need to select a battery that can handle the weight and power requirements of your motorcycle. Lead-acid batteries are common for e-bikes, but lithium-ion (Li-ion) or lithium-polymer (Li-po) batteries offer more energy density and longer lifespan.
# 3. **Controller**: The controller regulates the flow of electricity between the motor and battery. We'll need to choose a suitable controller that can handle the motor's power output and your desired level of assistance.
#
# To get started, let's assess your TVS XL Heavy Duty motorcycle:
#
# * What is your approximate weight, including rider and cargo?
# * What is your desired top speed for the e-bike?
# * Do you have any specific range requirements (e.g., daily commute or long trips)?
# * Are there any modifications you'd like to make to the bike's suspension, brakes, or handling?
#
# Once we have a better understanding of your needs and preferences, I can provide guidance on:
#
# 1. Choosing the right motor for your TVS XL.
# 2. Selecting an appropriate battery pack with adequate capacity and lifespan.
# 3. Designing a suitable controller system that suits your motor and battery choices.
# 4. Planning any necessary modifications to the motorcycle's suspension, brakes, or handling.
#
# Let me know if you have any questions or concerns, and we can take it from there!
