# %%
import ollama

# %%
messages = []
system_msg = input("What type of chatbot would you like to create?\n")
messages.append({"role": "system", "content": system_msg})

print("Your new assistant is ready!")

while True:
    user_input = input()
    if user_input.lower() == "quit":
        break

    messages.append({"role": "user", "content": user_input})

    response = ollama.chat(model="llama3", messages=messages)

    reply = response["message"]["content"]
    messages.append({"role": "assistant", "content": reply})

    print("\n" + reply + "\n")
# Out:
# What type of chatbot would you like to create?
#  book writing assisstant
# Your new assistant is ready!
#  what are some trending books in Fiction
# Here are some trending books in fiction across various genres:
#
# **Romance**
#
# 1. "The Hating Game" by Sally Thorne (a romantic comedy about two co-workers who engage in a series of pranks and one-upmanship)
# 2. "The Last Letter from Your Lover" by Jojo Moyes (a historical romance about a journalist who discovers a cache of old letters and becomes obsessed with uncovering the story behind them)
# 3. "The Honey-Don't List" by Christina Lauren (a romantic comedy about two opposites-attract assistants who work for a famous home renovation couple)
#
# **Mystery/Thriller**
#
# 1. "Gone Girl" by Gillian Flynn (a psychological thriller about a marriage that takes a dark and unexpected turn)
# 2. "The Silent Patient" by Alex Michaelides (a psychological thriller about a famous painter who shoots her husband and then refuses to speak or cooperate with the police)
# 3. "The 7 1/2 Deaths of Evelyn Hardcastle" by Stuart Turton (a murder mystery that takes place at a country manor in the early 20th century, where the main character is trapped in a cycle of death and rebirth)
#
# **Science Fiction**
#
# 1. "The Three-Body Problem" by Liu Cixin (a science fiction novel about first contact with an alien civilization)
# 2. "The Power" by Naomi Alderman (a speculative fiction novel that explores a world where women suddenly develop the ability to release electrical jolts from their fingertips, allowing them to dominate and oppress men)
# 3. "The First Fifteen Lives of Octavia Butler" by Nnedi Okorafor (a science fiction novel that reimagines the life of celebrated author Octavia Butler as a superhero)
#
# **Fantasy**
#
# 1. "The Name of the Wind" by Patrick Rothfuss (a fantasy novel about a musician and legend in his own time who recounts his adventures to a chronicler)
# 2. "The Poppy War" by R.F. Kuang (a fantasy novel set in a world inspired by Chinese history and mythology, where a young orphan enrolls in a prestigious military academy)
# 3. "The Fifth Season" by N.K. Jemisin (a fantasy novel that takes place in a world where natural disasters called "Fifth Seasons" have caused widespread destruction and chaos)
#
# **Young Adult**
#
# 1. "The Hate U Give" by Angie Thomas (a young adult novel about a teenage girl who witnesses the fatal shooting of her unarmed friend by a police officer)
# 2. "The Giver" by Lois Lowry (a dystopian novel that explores themes of memory, identity, and freedom in a society where all emotions and memories are controlled)
# 3. "To All the Boys I've Loved Before" by Jenny Han (a young adult romance novel about a high school girl whose secret love letters are accidentally sent to her crushes)
#
# These are just a few examples of trending books in fiction. Trends can vary depending on the audience, genre, and market conditions.
#  quit
